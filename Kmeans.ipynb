# %% [markdown]
# # K-means Algorithm
#
# ### Presented By- Raghav
#
# # Importing the libraries
# - numpy for mathematical operations
# - matplot is for ploting graphs
# - pandas for managing the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing the dataset
#
# - Reading the dataset csv file
# - : is to get all the rows and [3,4] is that what columns user wants

# %%
dataset = pd.read_csv('Mall_Customers.csv')   
X = dataset.iloc[:, [3,4]].values

# %% [markdown]
# # Using the elbow method to find the optimal number of clusters
# - Simple and efficient tools for data mining and data analysis
# - wcss means within cluster of squares used in elbow method
# - creating object of class kmeans and passing parameters

# %%
from sklearn.cluster import KMeans
wcss = [] #list wcss
for i in range(1,11):
    kmeans = KMeans(n_clusters =  i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X)  
    wcss.append(kmeans.inertia_) 
plt.plot(range(1,11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ## Sklearn
# # Applying K-means to the dataset
# - fit is a class of kmeans which used to fit data
# - applying kmeans algo to datasetbut thistime with right no ofdataset

# %%
kmeans = KMeans(n_clusters =  5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# %% [markdown]
# # Visualizing the clusters
# - ploting the centroids that which client belongs to which cluster

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Careful')  
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Standard')  
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Target')  
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Careless')  
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Sensible')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s = 300, c = 'yellow', label = 'Centroids') #plotting the centroids
plt.title('Clusters of customers')                                            #cluster_centers_ returns the coordinates of the centroids
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
